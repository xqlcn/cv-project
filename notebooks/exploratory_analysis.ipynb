# %% [markdown]
# # Exploratory analysis
#
# Load `data/metadata/chirality_index.jsonl` and `data/features/*/features_index.jsonl` to sanity-check counts, label balance, and cosine similarity pairs before full sweeps.

# %%
from pathlib import Path
import json
import pandas as pd

root = Path("..").resolve()
meta = root / "data/metadata/chirality_index.jsonl"
rows = [json.loads(l) for l in meta.read_text().splitlines() if l.strip()]
pd.DataFrame(rows).head()
